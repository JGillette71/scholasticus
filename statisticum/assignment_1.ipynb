# %% [markdown]
# #  Assignment 1
#
# STA-6543
#
# Jason Gillette

# %% [markdown]
# ### Problem 2
#
# Explain whether each scenario is a classification or regression problem, and indicate whether we are most interested in inference or prediction. Finally, provide n and p.
#
# (a) We collect a set of data on the top 500 firms in the US. For each firm we record profit, number of employees, industry and the CEO salary. We are interested in understanding which factors affect CEO salary.
#
# (b) We are considering launching a new product and wish to know whether it will be a success or a failure. We collect data on 20 similar products that were previously launched. For each product we have recorded whether it was a success or failure, price charged for the product, marketing budget, competition price, and ten other variables.
#
# (c) We are interested in predicting the % change in the USD/Euro exchange rate in relation to the weekly changes in the world stock markets. Hence we collect weekly data for all of 2012. For each week we record the % change in the USD/Euro, the % change in the US market, the % change in the British market, and the % change in the German market.

# %% [markdown]
# (a) This is a **regression** problem as our output variable (y) is a continuous value, not categorical. This is also an **inference** problem as we are seeking to better understand the relationship between two or more variables. Our number of samples (n) = 500 firms and our input variables (X~p) = 4.
#
# (b) This is a **classification** problem due to the categorical nature of the output variable, success or failure. This is a **prediction** since we seek to determine an output variable. In this scenario (n) = 20 similar products and (p) = 13 representing the input variables listed.
#
# (c) This is a **regression** problem as we seek to **predict** a continuous value in percentage change versus a categorical value like positive or negative. This is a prediction because the output variable is unknown. in this scenario n = 52 for each week of data collected and p = 3 for each market mentioned.

# %% [markdown]
# ### Problem 5
#
# What are the advantages and disadvantages of a very flexible (versus a less flexible) approach for regression or classification? Under what circumstances might a more flexible approach be preferred to a less flexible approach? When might a less flexible approach be preferred?

# %% [markdown]
# The advantage of a more flexible model is that it often results in a more accurate fit in both regression and classification problems. In the case of a regression problem, we may employ a more flexible model that better fits all samples in training data while in classification, the more flexible method may fit a more accurate decision boundary. However, there is a trade-off between flexibility and interpretability, leading to less explainable relationships between variables for inference problems. What's more is that highly flexible models are prone to over-fitting training data. Thus we may seek a less flexible model in order to better generalize predictions on unseen test data.

# %% [markdown]
# ### Problem 6
#
# Describe the differences between a parametric and a non-parametric statistical learning approach. What are the advantages of a parametric approach to regression or classification (as opposed to a nonparametric approach)? What are its disadvantages?

# %% [markdown]
# Parametric methods refer to a class of methods where the problem of estimating systemic information $f(x)$ is reduced to estimating a set of parameters applied to input variables. This is often seen as making an informed assumption about the underlying functional form, e.g., linear, logistic, etc., then applying a weight $\\b_p$ to each of the inputs variable to reflect its relative influence on the response variable. Parametric methods contrast non-parametric methods because there is no assumption of the underlying form, thus non-parametric method are significantly more flexible, but also more complex. The advantage of parametric methods is the increased simplicity and interpretability. However, parametric methods may be inadequate for more complex data as assumed functional form may be a poor fit.

# %% [markdown]
# ### Problem 8
#
# (a) Use the `pd.read_csv()` function to read the data into Python. Call the loaded data college. Make sure that you have the directory set to the correct location for the data.
#
# (b) Look at the data used in the notebook by creating and running a new cell with just the code college in it. You should notice that the first column is just the name of each university in a column named something like `Unnamed: 0`. We don’t really want pandas to treat this as data. However, it may be handy to have these names for later.
#
# (c) Use the describe() method of to produce a numerical summary of the variables in the data set.
#
# (d) Use the pd.plotting.scatter_matrix() function to produce a scatter plot matrix of the first columns [`Top10perc`, `Apps`, `Enroll`]. Recall that you can reference a list C of columns of a data frame A using `A[C]`.
#
# (e) Use the box plot() method of college to produce side-by-side box plots of `Outstate` versus `Private`.
#
# (f) Create a new qualitative variable, called `Elite`, by binning the `Top10perc` variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%. Use the `value_counts()` method of `college['Elite']` to see how many elite universities there are. Finally, use the `boxplot()` method again to produce side-by-side box plots of `Outstate` versus `Elite`.
#
# (g) Use the plot.hist() method of college to produce some histograms with differing numbers of bins for a few of the quantitative variables. The command plt.subplots(2, 2) may be useful: it will divide the plot window into four regions so that four plots can be made simultaneously. By changing the arguments you can divide the screen up in other combinations.
#
# (h) Continue exploring the data, and provide a brief summary of what you discover.

# %%
import os
import pandas as pd
import numpy as np

# update working directory
os.chdir("/home/userj/projects/statisticum")
print(f"{os.getcwd()}\n")

# part a / part b
college = pd.read_csv("College.csv")
college = college.rename({'Unnamed: 0': 'College'}, axis=1)
college = college.set_index('College')
print(f"Call the loaded data:\n{college.head()}\n")
# Out:
# /home/userj/projects/statisticum
#
# Call the loaded data:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
# part b
describe_college = college.describe()
print(f"Numerical Summary:\n{describe_college}")
# Out:
# Numerical Summary:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# part d 
scatter_plot = pd.plotting.scatter_matrix(college[["Top10perc", "Apps", "Enroll"]])
print(f"Scatter Plot Matrix:\n{scatter_plot}")
# Out:
# Scatter Plot Matrix:
# [[<Axes: xlabel='Top10perc', ylabel='Top10perc'>
#   <Axes: xlabel='Apps', ylabel='Top10perc'>
#   <Axes: xlabel='Enroll', ylabel='Top10perc'>]
#  [<Axes: xlabel='Top10perc', ylabel='Apps'>
#   <Axes: xlabel='Apps', ylabel='Apps'>
#   <Axes: xlabel='Enroll', ylabel='Apps'>]
#  [<Axes: xlabel='Top10perc', ylabel='Enroll'>
#   <Axes: xlabel='Apps', ylabel='Enroll'>
#   <Axes: xlabel='Enroll', ylabel='Enroll'>]]

# %%
# part e
college['Private'] = college['Private'].astype('category')
college.boxplot(column='Outstate', by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %%
# part f
college["portion_elite"] = college["Top10perc"] / college["Enroll"]
college['Elite'] = pd.cut(college['portion_elite'], [0,0.5,1], labels=['No', 'Yes'])
print(f"How many colleges are elite?\n{college.Elite.value_counts()}\n")
college['Elite'] = college['Elite'].astype('category')
college.boxplot(column='Outstate', by='Elite')
# Out:
# How many colleges are elite?
# Elite
# No     775
# Yes      2
# Name: count, dtype: int64
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %%
#part g
college["Undergrads"] = college["F.Undergrad"] + college["P.Undergrad"]
selected_columns = ["Apps", "Accept", "Enroll", "Undergrads"]
college[selected_columns].hist(bins=10, layout=(2, 2))
# Out:
# array([[<Axes: title={'center': 'Apps'}>,
#         <Axes: title={'center': 'Accept'}>],
#        [<Axes: title={'center': 'Enroll'}>,
#         <Axes: title={'center': 'Undergrads'}>]], dtype=object)

# %%
# part h
scatter_data = college[["Apps", "Accept", "Enroll", "Undergrads"]]
pd.plotting.scatter_matrix(scatter_data, figsize=(8, 8))
# Out:
# array([[<Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Accept', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>,
#         <Axes: xlabel='Undergrads', ylabel='Apps'>],
#        [<Axes: xlabel='Apps', ylabel='Accept'>,
#         <Axes: xlabel='Accept', ylabel='Accept'>,
#         <Axes: xlabel='Enroll', ylabel='Accept'>,
#         <Axes: xlabel='Undergrads', ylabel='Accept'>],
#        [<Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Accept', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>,
#         <Axes: xlabel='Undergrads', ylabel='Enroll'>],
#        [<Axes: xlabel='Apps', ylabel='Undergrads'>,
#         <Axes: xlabel='Accept', ylabel='Undergrads'>,
#         <Axes: xlabel='Enroll', ylabel='Undergrads'>,
#         <Axes: xlabel='Undergrads', ylabel='Undergrads'>]], dtype=object)

# %% [markdown]
# #### part h (cont.)
#
# A scatter plot matrix allows us to perform inference on several quantitative variables concerning students that apply, get accepted, and enroll relative to the size of the school in terms of total undergraduate population. While a positive relationship is expected, the degree of each relationship is visualized by the slope in each respective plot. For example, we can observe that undergraduate population has a moderate positive correlation to the number of applications with an increasingly positive relationship relative to acceptance and then enrollment. From this we can hypothesize that larger schools simply accept and enroll more students versus receiving more applicants, suggesting a lower barrier to entry.

# %% [markdown]
# ### Problem 9
#
# (a) Which of the predictors are quantitative, and which are qualitative?
#
# (b) What is the range of each quantitative predictor? You can answer this using the `min()` and `max()` methods in `numpy.min()`.
#
# (c) What is the mean and standard deviation of each quantitative `.max()` predictor?
#
# (d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?
#
# (e) Using the full data set, investigate the predictors graphically, using scatter plots or other tools of your choice. Create some plots
# highlighting the relationships among the predictors. Comment on your findings.
#
# (f) Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.

# %%
# part a
setwd("/home/userj/projects/statisticum")
auto <- read.csv("Auto.csv")
head(auto)
# Out:
#   mpg cylinders displacement horsepower weight acceleration year origin
# 1 18  8         307          130        3504   12.0         70   1
# 2 15  8         350          165        3693   11.5         70   1
# 3 18  8         318          150        3436   11.0         70   1
# 4 16  8         304          150        3433   12.0         70   1
# 5 17  8         302          140        3449   10.5         70   1
# 6 15  8         429          198        4341   10.0         70   1
#   name
# 1 chevrolet chevelle malibu
# 2 buick skylark 320
# 3 plymouth satellite
# 4 amc rebel sst
# 5 ford torino
# 6 ford galaxie 500

# %% [markdown]
# #### part a (cont.)
#
# Features `origin` and `name` appear to be qualitative while the other 7 features are quantitative.

# %%
# part b
quant_cols <- c("mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "year")

for (col in quant_cols) {
    auto[[col]][auto[[col]] == "?"] <- NA
    auto[[col]] <- as.numeric(auto[[col]])
    cat(col, "Range:", range(auto[[col]], na.rm = TRUE), "\n")
}
# Out:
# mpg Range: 9 46.6
# cylinders Range: 3 8
# displacement Range: 68 455
# horsepower Range: 46 230
# weight Range: 1613 5140
# acceleration Range: 8 24.8
# year Range: 70 82

# %%
# part c
# this question is not clear...

for (col in quant_cols) {
    mean_value <- mean(auto[[col]], na.rm = TRUE)
    sd_value <- sd(auto[[col]], na.rm = TRUE)
    
    cat(col, "- Mean:", mean_value, "Std Dev:", sd_value, "\n")
}
# Out:
# mpg - Mean: 23.51587 Std Dev: 7.825804
# cylinders - Mean: 5.458438 Std Dev: 1.701577
# displacement - Mean: 193.5327 Std Dev: 104.3796
# horsepower - Mean: 104.4694 Std Dev: 38.49116
# weight - Mean: 2970.262 Std Dev: 847.9041
# acceleration - Mean: 15.55567 Std Dev: 2.749995
# year - Mean: 75.99496 Std Dev: 3.690005

# %%
# part d
auto_b <- auto[-(10:85), ]

for (col in quant_cols) {
    auto_b[[col]][auto_b[[col]] == "?"] <- NA
    auto_b[[col]] <- as.numeric(auto_b[[col]])
    range <- range(auto_b[[col]], na.rm = TRUE)
    mean_value <- mean(auto_b[[col]], na.rm = TRUE)
    sd_value <- sd(auto_b[[col]], na.rm = TRUE)
    
    cat(col, "- Mean:", mean_value, "Std Dev:", sd_value, "Range:", range, "\n")
}
# Out:
# mpg - Mean: 24.43863 Std Dev: 7.908184 Range: 11 46.6
# cylinders - Mean: 5.370717 Std Dev: 1.653486 Range: 3 8
# displacement - Mean: 187.0498 Std Dev: 99.63539 Range: 68 455
# horsepower - Mean: 100.9558 Std Dev: 35.89557 Range: 46 230
# weight - Mean: 2933.963 Std Dev: 810.6429 Range: 1649 4997
# acceleration - Mean: 15.72305 Std Dev: 2.680514 Range: 8.5 24.8
# year - Mean: 77.15265 Std Dev: 3.11123 Range: 70 82

# %%
# part e
par(bg = "lightgray")  
pairs(auto[, c("mpg", "horsepower", "weight", "acceleration")], 
      main = "Pairwise Scatter Plots",
      pch = 16, col = "blue")
# Out:
# plot without title

# %% [markdown]
# #### part f
#
# When examining which variables serve as strong predictors of gas milage, `horsepower` and `weight` prove to have strong negative relationships. The scatter plot demonstrates that even a simple linear model with an input variable `weight` could provide ballpark predictions of `mpg` with a high degree of accuracy.

# %% [markdown]
# ### Problem 10
#
# (a) To begin, load in the Boston data set, which is part of the ISLP library.
#
# (b) How many rows are in this data set? How many columns? What do the rows and columns represent?
#
# (c) Make some pairwise scatter plots of the predictors (columns) in this data set. Describe your findings.
#
# (d) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.
#
# (e) Do any of the suburbs of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.
#
# (f) How many of the suburbs in this data set bound the Charles river?
#
# (g) What is the median pupil-teacher ratio among the towns in this data set?
#
# (h) Which suburb of Boston has lowest median value of owner occupied homes? What are the values of the other predictors for that suburb, and how do those values compare to the overall ranges for those predictors? Comment on your findings.
#
# (i) In this data set, how many of the suburbs average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the suburbs that average more than eight rooms per dwelling.

# %%
# part a
from ISLP import load_data

boston = load_data("Boston")
print(boston.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
#part b
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  lstat    506 non-null    float64
#  12  medv     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %% [markdown]
# #### part b (cont.)
#
# | **Variable** | **Description** |
# |--------------|-----------------|
# | `crim`      | Per capita crime rate by town |
# | `zn`        | Proportion of residential land zoned for large lots (over 25,000 sq. ft.) |
# | `indus`     | Proportion of non-retail business acres per town |
# | `chas`      | Charles River dummy variable (1 if the tract bounds the river, 0 otherwise) |
# | `nox`       | Nitrogen oxides concentration (parts per 10 million) |
# | `rm`        | Average number of rooms per dwelling |
# | `age`       | Proportion of owner-occupied units built before 1940 |
# | `dis`       | Weighted distance to five major Boston employment centers |
# | `rad`       | Index of accessibility to radial highways |
# | `tax`       | Property tax rate per $10,000 |
# | `ptratio`   | Pupil-to-teacher ratio by town |
# | `lstat`     | Percentage of lower-income population |
# | `medv`      | Median home value ($1000s) (Response Variable) |
#
# data dictionary sources [here](https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html)

# %%
#part c
import pandas as pd

subset = boston[["crim", "rm", "lstat", "medv", "dis", "age"]]

pd.plotting.scatter_matrix(subset)
# Out:
# array([[<Axes: xlabel='crim', ylabel='crim'>,
#         <Axes: xlabel='rm', ylabel='crim'>,
#         <Axes: xlabel='lstat', ylabel='crim'>,
#         <Axes: xlabel='medv', ylabel='crim'>,
#         <Axes: xlabel='dis', ylabel='crim'>,
#         <Axes: xlabel='age', ylabel='crim'>],
#        [<Axes: xlabel='crim', ylabel='rm'>,
#         <Axes: xlabel='rm', ylabel='rm'>,
#         <Axes: xlabel='lstat', ylabel='rm'>,
#         <Axes: xlabel='medv', ylabel='rm'>,
#         <Axes: xlabel='dis', ylabel='rm'>,
#         <Axes: xlabel='age', ylabel='rm'>],
#        [<Axes: xlabel='crim', ylabel='lstat'>,
#         <Axes: xlabel='rm', ylabel='lstat'>,
#         <Axes: xlabel='lstat', ylabel='lstat'>,
#         <Axes: xlabel='medv', ylabel='lstat'>,
#         <Axes: xlabel='dis', ylabel='lstat'>,
#         <Axes: xlabel='age', ylabel='lstat'>],
#        [<Axes: xlabel='crim', ylabel='medv'>,
#         <Axes: xlabel='rm', ylabel='medv'>,
#         <Axes: xlabel='lstat', ylabel='medv'>,
# ...

# %% [markdown]
# #### part d
#
# There appears to be no strong predictors of crime rate in this dataset. There is some moderate relationships on the response variable, including a negative relationship to median income (`medv`), a negative relationship to distance from major employment centers (`dis`). Other variables may need additional normalization to reveal a relationship.

# %%
# part e
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# #### part e (cont.)
#
# The maximum crime rates observed in the data is 89. However, it is unclear if this measure is nominal per 100,000 or a different measure. The lowest crime rate observed is 0.006. If this dataset normalizes crime data as crimes per 100,000 people, then Boston is significantly below the national average of ~380. The maximum tax rate observed is $711 per $10,000, a rate of 7.11% while the lowest rate is 1.87%. Pupil-teacher ratio ranges from 1.73 pupils per teacher to 38 per teacher. The data is insufficient to identify which Boston suburbs align to the maximum values.

# %%
# part f

boston["chas"].value_counts()

# 35 bound by charles river
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
# part g

boston["ptratio"].median()
# Out:
# 19.05

# %%
# part h

lowest_medv_row = boston.loc[boston["medv"].idxmin()]

lowest_medv_row
# Out:
# crim        38.3518
# zn           0.0000
# indus       18.1000
# chas         0.0000
# nox          0.6930
# rm           5.4530
# age        100.0000
# dis          1.4896
# rad         24.0000
# tax        666.0000
# ptratio     20.2000
# lstat       30.5900
# medv         5.0000
# Name: 398, dtype: float64

# %% [markdown]
# #### part h (cont.)
#
# The values associated with the lowest median home values suggest a higher than average crime rate, greater than average pollution, fewer rooms, and more homes built before 1940. Overall the area has higher than average tax rates, and are closer to major roads and businesses. Comparing this suburb in terms of owner-occupied is not conclusive as that data point is not available for beyond homes built before 1940.

# %%
# part i

boston["rm_bins"] = pd.cut(boston["rm"], bins=[0, 7, 8, float("inf")], labels=["≤7 rooms", "7-8 rooms", ">8 rooms"])
boston["rm_bins"].value_counts()
# Out:
# rm_bins
# ≤7 rooms     442
# 7-8 rooms     51
# >8 rooms      13
# Name: count, dtype: int64

# %%
samples_above_7 = boston[boston["rm"] > 7]
print(samples_above_7.describe())
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  64.000000  64.000000  64.000000  64.000000  64.000000  64.000000
# mean    0.979109  28.171875   5.775625   0.125000   0.504455   7.570094
# std     2.807599  34.053089   5.544494   0.333333   0.092863   0.481467
# min     0.009060   0.000000   0.460000   0.000000   0.394000   7.007000
# 25%     0.045023   0.000000   2.460000   0.000000   0.430250   7.183250
# 50%     0.097860  20.000000   3.970000   0.000000   0.488000   7.414000
# 75%     0.542893  45.000000   6.200000   0.000000   0.582500   7.858500
# max    19.609100  95.000000  19.580000   1.000000   0.718000   8.780000
#
#               age        dis        rad         tax    ptratio      lstat  \
# count   64.000000  64.000000  64.000000   64.000000  64.000000  64.000000
# mean    60.640625   4.199617   5.984375  312.234375  16.259375   5.474062
# std     27.858587   2.074423   5.655429  118.311365   2.351407   2.906582
# ...

# %%
samples_above_8 = boston[boston["rm"] > 8]
print(samples_above_8.describe())
# Out:
#             crim         zn      indus       chas        nox         rm  \
# count  13.000000  13.000000  13.000000  13.000000  13.000000  13.000000
# mean    0.718795  13.615385   7.078462   0.153846   0.539238   8.348538
# std     0.901640  26.298094   5.392767   0.375534   0.092352   0.251261
# min     0.020090   0.000000   2.680000   0.000000   0.416100   8.034000
# 25%     0.331470   0.000000   3.970000   0.000000   0.504000   8.247000
# 50%     0.520140   0.000000   6.200000   0.000000   0.507000   8.297000
# 75%     0.578340  20.000000   6.200000   0.000000   0.605000   8.398000
# max     3.474280  95.000000  19.580000   1.000000   0.718000   8.780000
#
#              age        dis        rad         tax    ptratio      lstat  \
# count  13.000000  13.000000  13.000000   13.000000  13.000000  13.000000
# mean   71.538462   3.430192   7.461538  325.076923  16.361538   4.310000
# std    24.608723   1.883955   5.332532  110.971063   2.410580   1.373566
# ...

# %% [markdown]
# #### part i (cont.)
#
# Samples that average 8+ rooms tend to have a higher median value, lower crime rates, and slightly higher taxes. Interesting that these areas also have greater industry and pollution compared to Suburbs that average 7 rooms.
